# %%
import paho.mqtt.client as mqtt
import time
from datetime import datetime
import random
import json
from random import randint
import os

#mqtt_broker_host = "172.208.48.92"
mqtt_broker_host = "localhost"
mqtt_broker_port = 1883
# mqtt_topic = "sensor/binary"
device_id_base = "binarySensor"
device_id_counter = 1


list_sensors = ["cocina_puerta","cocina_frigo", "dormitorio_puerta", "dormitorio_presencia", "wc_puerta", "salon_presencia"]

# Función para simular el sensor binario
def simulate_binary_sensor():
    timestamp = datetime.now().isoformat()  # Obtén la fecha y hora actual en formato ISO
    sensor_data = []

    for sensor_type in list_sensors:
        sensor_value = bool(randint(0, 1))  # Genera un valor aleatorio para el sensor
        sensor_value_str = "1" if sensor_value else "0"  # Convierte el valor del sensor a "1" o "0"
        sensor_data.append(f"timestamp_sensor|{timestamp}|activo|{sensor_value_str}|tipo_sensor|{sensor_type}")

    return sensor_data

def on_publish(client, userdata, mid):
    print(f"Mensaje publicado con éxito (ID: {mid})")
    
def getTime():
    return str(int(time.time()))+"\t"+datetime.now().strftime("%Y-%m-%d %H:%M:%S")

print("Config Client")
# Configuración del cliente MQTT
client = mqtt.Client()
client.on_publish = on_publish

# Conexión al broker MQTT
client.connect(mqtt_broker_host, mqtt_broker_port, keepalive=60)
client.loop_start()

try:
    while True:
        # Simula la generación de un mensaje aleatorio
        sensor_data_list = simulate_binary_sensor()

        for sensor_data in sensor_data_list:
            device_id = f"{device_id_base}{device_id_counter:03d}"
            topic = f"/ul/4jggokgpepnvsb2uv4s40d59ov/{device_id}/attrs"

            # Publica el mensaje en el topic
            result = client.publish(topic, sensor_data, qos=2)
            print("mqtt_topic->", topic, "sensor_data->", sensor_data, "result->", result)

            device_id_counter += 1

        # Espera antes de la siguiente lectura
        time.sleep(randint(1,5))

except KeyboardInterrupt:
    print("Programa detenido por el usuario.")
    client.disconnect()
# Out:
# Config Client
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor001/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:10.627340|activo|1|tipo_sensor|cocina_puerta result-> (0, 1)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor002/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:10.627340|activo|1|tipo_sensor|cocina_frigo result-> (0, 2)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor003/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:10.627340|activo|1|tipo_sensor|dormitorio_puerta result-> (0, 3)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor004/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:10.627340|activo|0|tipo_sensor|dormitorio_presencia result-> (0, 4)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor005/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:10.627340|activo|0|tipo_sensor|wc_puerta result-> (0, 5)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor006/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:10.627340|activo|1|tipo_sensor|salon_presencia result-> (0, 6)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor007/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:15.631420|activo|0|tipo_sensor|cocina_puerta result-> (0, 7)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor008/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:15.631420|activo|0|tipo_sensor|cocina_frigo result-> (0, 8)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor009/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:15.631420|activo|0|tipo_sensor|dormitorio_puerta result-> (0, 9)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor010/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:15.631420|activo|0|tipo_sensor|dormitorio_presencia result-> (0, 10)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor011/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:15.631420|activo|0|tipo_sensor|wc_puerta result-> (0, 11)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor012/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:15.631420|activo|0|tipo_sensor|salon_presencia result-> (0, 12)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor013/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:20.636965|activo|0|tipo_sensor|cocina_puerta result-> (4, 13)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor014/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:20.636965|activo|1|tipo_sensor|cocina_frigo result-> (4, 14)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor015/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:20.636965|activo|0|tipo_sensor|dormitorio_puerta result-> (4, 15)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor016/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:20.636965|activo|0|tipo_sensor|dormitorio_presencia result-> (4, 16)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor017/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:20.636965|activo|0|tipo_sensor|wc_puerta result-> (4, 17)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor018/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:20.636965|activo|0|tipo_sensor|salon_presencia result-> (4, 18)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor019/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:21.638225|activo|1|tipo_sensor|cocina_puerta result-> (4, 19)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor020/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:21.638225|activo|1|tipo_sensor|cocina_frigo result-> (4, 20)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor021/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:21.638225|activo|1|tipo_sensor|dormitorio_puerta result-> (4, 21)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor022/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:21.638225|activo|1|tipo_sensor|dormitorio_presencia result-> (4, 22)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor023/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:21.638225|activo|1|tipo_sensor|wc_puerta result-> (4, 23)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor024/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:21.638225|activo|0|tipo_sensor|salon_presencia result-> (4, 24)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor025/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:22.639482|activo|1|tipo_sensor|cocina_puerta result-> (4, 25)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor026/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:22.639482|activo|1|tipo_sensor|cocina_frigo result-> (4, 26)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor027/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:22.639482|activo|0|tipo_sensor|dormitorio_puerta result-> (4, 27)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor028/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:22.639482|activo|0|tipo_sensor|dormitorio_presencia result-> (4, 28)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor029/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:22.639482|activo|0|tipo_sensor|wc_puerta result-> (4, 29)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor030/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:22.639482|activo|0|tipo_sensor|salon_presencia result-> (4, 30)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor031/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:23.640925|activo|0|tipo_sensor|cocina_puerta result-> (4, 31)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor032/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:23.640925|activo|1|tipo_sensor|cocina_frigo result-> (4, 32)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor033/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:23.640925|activo|0|tipo_sensor|dormitorio_puerta result-> (4, 33)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor034/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:23.640925|activo|1|tipo_sensor|dormitorio_presencia result-> (4, 34)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor035/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:23.640925|activo|0|tipo_sensor|wc_puerta result-> (4, 35)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor036/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:23.640925|activo|0|tipo_sensor|salon_presencia result-> (4, 36)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor037/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:28.644942|activo|1|tipo_sensor|cocina_puerta result-> (4, 37)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor038/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:28.644942|activo|1|tipo_sensor|cocina_frigo result-> (4, 38)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor039/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:28.644942|activo|1|tipo_sensor|dormitorio_puerta result-> (4, 39)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor040/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:28.644942|activo|0|tipo_sensor|dormitorio_presencia result-> (4, 40)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor041/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:28.644942|activo|1|tipo_sensor|wc_puerta result-> (4, 41)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor042/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:28.644942|activo|1|tipo_sensor|salon_presencia result-> (4, 42)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor043/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:29.646178|activo|0|tipo_sensor|cocina_puerta result-> (4, 43)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor044/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:29.646178|activo|0|tipo_sensor|cocina_frigo result-> (4, 44)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor045/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:29.646178|activo|1|tipo_sensor|dormitorio_puerta result-> (4, 45)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor046/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:29.646178|activo|0|tipo_sensor|dormitorio_presencia result-> (4, 46)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor047/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:29.646178|activo|0|tipo_sensor|wc_puerta result-> (4, 47)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor048/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:29.646178|activo|0|tipo_sensor|salon_presencia result-> (4, 48)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor049/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:32.649225|activo|1|tipo_sensor|cocina_puerta result-> (4, 49)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor050/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:32.649225|activo|0|tipo_sensor|cocina_frigo result-> (4, 50)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor051/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:32.649225|activo|0|tipo_sensor|dormitorio_puerta result-> (4, 51)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor052/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:32.649225|activo|0|tipo_sensor|dormitorio_presencia result-> (4, 52)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor053/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:32.649225|activo|1|tipo_sensor|wc_puerta result-> (4, 53)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor054/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:32.649225|activo|1|tipo_sensor|salon_presencia result-> (4, 54)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor055/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:34.652757|activo|1|tipo_sensor|cocina_puerta result-> (4, 55)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor056/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:34.652757|activo|1|tipo_sensor|cocina_frigo result-> (4, 56)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor057/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:34.652757|activo|0|tipo_sensor|dormitorio_puerta result-> (4, 57)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor058/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:34.652757|activo|1|tipo_sensor|dormitorio_presencia result-> (4, 58)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor059/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:34.652757|activo|1|tipo_sensor|wc_puerta result-> (4, 59)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor060/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:34.652757|activo|0|tipo_sensor|salon_presencia result-> (4, 60)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor061/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:39.656957|activo|0|tipo_sensor|cocina_puerta result-> (4, 61)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor062/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:39.656957|activo|0|tipo_sensor|cocina_frigo result-> (4, 62)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor063/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:39.656957|activo|1|tipo_sensor|dormitorio_puerta result-> (4, 63)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor064/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:39.656957|activo|1|tipo_sensor|dormitorio_presencia result-> (4, 64)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor065/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:39.656957|activo|0|tipo_sensor|wc_puerta result-> (4, 65)
# mqtt_topic-> /ul/4jggokgpepnvsb2uv4s40d59ov/binarySensor066/attrs sensor_data-> timestamp_sensor|2024-06-08T19:21:39.656957|activo|0|tipo_sensor|salon_presencia result-> (4, 66)
# Programa detenido por el usuario.
