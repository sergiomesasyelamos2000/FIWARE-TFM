# %%
import paho.mqtt.client as mqtt
import time
from datetime import datetime
import random
import json
from random import randint
import os

mqtt_broker_host = "localhost"
mqtt_broker_port = 1883
# mqtt_topic = "sensor/location"
location_id_base = "locationUser"
location_id_counter = 1


list_users = ["A","B","C"]


def getPosMinMax():
    xA=randint(0,100)
    xB=randint(0,100)
    
    x1=min(xA,xB)
    x2=max(xA,xB)
    return x1,x2

# Función para simular el sensor binario
def simulate_binary_sensor():
    # Simula la lectura del sensor
    x1,x2=getPosMinMax()
    y1,y2=getPosMinMax()
    uncertain=random.uniform(0, 1)
    
    user_id=random.choice(list_users)
    timestamp = datetime.now().isoformat()  # Obtén la fecha y hora actual en formato ISO

    #return getTime()+"\t"+user_id+"\t"+str(x1)+"\t"+str(x2)+"\t"+str(y1)+"\t"+str(y2)+"\t"+str(uncertain)
    # Genera el mensaje en el formato que necesitas
    message = f"timestamp_sensor|{timestamp}|x1|{x1}|x2|{x2}|y1|{y1}|y2|{y2}|uncertain|{uncertain}|user_id|{user_id}"
    return message

def on_publish(client, userdata, mid):
    print(f"Mensaje publicado con éxito (ID: {mid})")
    
def getTime():
    return str(int(time.time()))+"\t"+datetime.now().strftime("%Y-%m-%d %H:%M:%S")

print("Config Client")
# Configuración del cliente MQTT
client = mqtt.Client()
client.on_publish = on_publish

# Conexión al broker MQTT
client.connect(mqtt_broker_host, mqtt_broker_port, keepalive=60)
client.loop_start()

try:
    while True:
        # Simula la generación de un mensaje aleatorio
        sensor_data = simulate_binary_sensor()

        location_id = f"{location_id_base}{location_id_counter:03d}"

        topic = f"/ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/{location_id}/attrs"

        # Publica el mensaje en el topic
        result = client.publish(topic, sensor_data, qos=2)
        print("mqrr_topic->", topic, "sensor_data->", sensor_data, "result->", result)
        
        location_id_counter += 1

        # Espera antes de la siguiente lectura
        time.sleep(randint(1,5))

except KeyboardInterrupt:
    print("Programa detenido por el usuario.")
    client.disconnect()
# Out:
# Config Client
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser001/attrs sensor_data-> timestamp_sensor|2024-01-04T11:55:55.183801|x1|2|x2|25|y1|39|y2|99|uncertain|0.6562715268298174|user_id|B result-> (0, 1)
# Mensaje publicado con éxito (ID: 1)
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser002/attrs sensor_data-> timestamp_sensor|2024-01-04T11:56:00.185199|x1|17|x2|45|y1|51|y2|83|uncertain|0.3276786379886809|user_id|A result-> (0, 2)
# Mensaje publicado con éxito (ID: 2)
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser003/attrs sensor_data-> timestamp_sensor|2024-01-04T11:56:03.188861|x1|12|x2|38|y1|59|y2|75|uncertain|0.6548511443241667|user_id|C result-> (0, 3)
# Mensaje publicado con éxito (ID: 3)
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser004/attrs sensor_data-> timestamp_sensor|2024-01-04T11:56:06.191423|x1|20|x2|34|y1|31|y2|65|uncertain|0.8911421305107946|user_id|B result-> (0, 4)
# Mensaje publicado con éxito (ID: 4)
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser005/attrs sensor_data-> timestamp_sensor|2024-01-04T11:56:07.193188|x1|24|x2|53|y1|15|y2|95|uncertain|0.3250627595644643|user_id|C result-> (0, 5)
# Mensaje publicado con éxito (ID: 5)
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser006/attrs sensor_data-> timestamp_sensor|2024-01-04T11:56:09.195873|x1|23|x2|89|y1|39|y2|88|uncertain|0.3914529434804992|user_id|C result-> (0, 6)
# Mensaje publicado con éxito (ID: 6)
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser007/attrs sensor_data-> timestamp_sensor|2024-01-04T11:56:10.197115|x1|14|x2|30|y1|27|y2|87|uncertain|0.15894022852380674|user_id|C result-> (0, 7)
# Mensaje publicado con éxito (ID: 7)
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser008/attrs sensor_data-> timestamp_sensor|2024-01-04T11:56:11.198690|x1|58|x2|87|y1|28|y2|30|uncertain|0.19034011901110381|user_id|A result-> (0, 8)
# Mensaje publicado con éxito (ID: 8)
# mqrr_topic-> /ul/f1aa255e-yfzd-4253-znvy-ee3dda78a28c/locationUser009/attrs sensor_data-> timestamp_sensor|2024-01-04T11:56:14.201093|x1|48|x2|80|y1|21|y2|49|uncertain|0.7062935260011839|user_id|B result-> (0, 9)
# Mensaje publicado con éxito (ID: 9)
# Programa detenido por el usuario.
